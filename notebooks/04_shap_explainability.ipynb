# %%
import shap
import matplotlib.pyplot as plt

# %%
import joblib

clf = joblib.load('../models/rating_bucket_classifier.joblib')
print(type(clf))
# Out:
# <class 'sklearn.ensemble._forest.RandomForestClassifier'>

# %%
# Clean test set
X_test_cleaned = X_test.drop(columns=[
    'country_cleaned', 'rating', 'rating_action_date', 'rating_year', 'rating_encoded'
], errors='ignore')

# %%
explainer = shap.TreeExplainer(clf)
shap_values = explainer.shap_values(X_test_cleaned)

# %%
shap.summary_plot(shap_values, X_test_cleaned, plot_type="bar")

# %%
plt.figure()
shap.summary_plot(shap_values, X_test_cleaned, show=False)
plt.tight_layout()
plt.savefig("../figures/shap_summary_classification.png", dpi=300)
plt.close()
